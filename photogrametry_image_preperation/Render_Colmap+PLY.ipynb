# %% [markdown]
# # A script to batch render colmap with custom .PLY in Blender 2.8

# %% [markdown]
# ## To run this script please use the blender photogrametry addon from:
#
#   https://github.com/stuarta0/blender-photogrammetry
#
#   A really great addon that imports the full colmap sparse construct scene, this means a scene that
#   constructs the cameras positions around a pointclound repressenting the scanned object.

# %% [markdown]
# ## This script takes you from a sparse constructed colmap scene to rendered and paired images ready for traininng.

# %%
import bpy
import os
import sys
import glob
import time
from PIL import Image, ImageFile
from shutil import copyfile

Path = './'

# %% [markdown]
# ## Loading the scene
#
# ### load_colmap(path, keep_points=False)
#     A function to load a colmap scene through the addon from the path arg.
#     The keep_points arg gives you the option to automatcaly delete the point cloud.

# %%
def load_colmap(path, keep_points=False):
    bpy.context.scene.photogrammetry.input = 'in_colmap'
    bpy.context.scene.photogrammetry.output = 'out_blender'
    bpy.context.scene.photogrammetry.in_colmap.dirpath = path
    bpy.context.scene.photogrammetry.out_blender.relative_paths = True
    bpy.context.scene.photogrammetry.out_blender.update_render_size = True
    bpy.context.scene.photogrammetry.out_blender.camera_alpha = 0
    bpy.ops.photogrammetry.process()
    if keep_points == False:
        
        bpy.ops.object.select_all(action='DESELECT')
        bpy.data.objects['PhotogrammetryPoints'].select_set(True)
        bpy.ops.object.delete() 
        
#load_colmap( "/home/gimms/Desktop/Image_2_Mesh/Rocks/rock1/sparse/0/")

# %% [markdown]
# ### load_mesh(path, addMat = True, wireframe=False)
#     A function that loads a .ply file into the scene from the path arg,
#     addMat defaults True and adds a shader that shows the .ply's vertex colours,
#     wireframe defaults False and is an option to create a duplicate geometry but in wireframe format

# %%
def load_mesh(path, addMat = True, wireframe=False):
    name = os.path.basename(os.path.normpath(path))
    bpy.ops.import_mesh.ply(filepath=path+"/"+name+"_Mesh+Col_HD.ply")
    
    ob = bpy.data.objects[name+'_Mesh+Col_HD']

    material = bpy.data.materials.get("Material")
    
    # Assign it to object
    if ob.data.materials:
        # assign to 1st material slot
        ob.data.materials[0] = material
    else:
        # no slots
        ob.data.materials.append(material)
    
    if wireframe:
        bpy.ops.import_mesh.ply(filepath=path+"/"+name+"_Mesh+Col_HD.ply")
        wireframe = bpy.data.objects[name+'_Mesh+Col_HD.001']
        frame = wireframe.modifiers.new(type = 'WIREFRAME', name = 'wireframe')
        frame.thickness = 0.0005
        bpy.ops.object.modifier_apply(apply_as='DATA', modifier=frame.name)
        # Assign it to object
        if wireframe.data.materials:
            # assign to 1st material slot
            wireframe.data.materials[0] = bpy.data.materials.get("Wireframe")
        else:
            # no slots
            wireframe.data.materials.append(bpy.data.materials.get("Wireframe"))

# %% [markdown]
# ### LoadScene(path)
#     A function that checks if the flies exist and if they do loads them and returns True,
#     if they don't returns False

# %%
def loadScene(path):
    name = os.path.basename(os.path.normpath(path))
    if os.path.exists(path+"/sparse/0") and os.path.exists(path+"/"+name+"_Mesh+Col_HD.ply"):
        
        load_colmap(path+"/sparse/0")  
        load_mesh(path, wireframe=False)
        
        return True
    else:
        return False

# %% [markdown]
# ## Rendering Functions
#
# ### render_all_cam(path, size, backgroundCol)
#
#     A function that runs through all the cameras in the scene and renders them out with numerical names
#     to the path arg, with width/height of size and with background.

# %%
def render_all_cam(path, size, backgroundCol):
    
    bpy.data.worlds["World"].node_tree.nodes["Background"].inputs[0].default_value = backgroundCol
    scene = bpy.context.scene
    #scene.render.image_settings.file_format = 'OpenEXR' # set output format to .png
    
    bpy.context.scene.render.resolution_x = size
    bpy.context.scene.render.resolution_y = size

    
    #num= len(glob.glob("./IMagedataBase/Images_Exr/exr/*.exr"))
    num=0
    for ob in bpy.context.scene.objects:
            if ob.type == 'CAMERA':
                bpy.context.scene.camera = ob
                
                #setuv_from_camera(ob)
                # set output path so render won't get overwritten
                num+=1
                number = str(num).zfill(5)
                scene.render.filepath = path + number
                bpy.ops.render.render(write_still=True) # render still

# %% [markdown]
# ### render_all_cam_encoder(path)
#
#     A failed attempt to encode vertices, faces, normals and wertex colors to a jpeg format,
#     to easilly enter it into pix2pix, but I changed course to exr encoding as I realised the
#     dificulty of making a nueral net for such a complex a translation as mesh to pix was
#     probably beyond me at this point.

# %%
'''           
def render_all_cam_encoder(path):   
    form = []
    for ob in bpy.context.scene.objects:
        if ob.type == 'MESH':
            
            

            color_layer = ob.data.vertex_colors
            pos_layer = ob.data.vertices
            uv_layer = ob.data.uv_layers.values()
            for vert, col in zip(ob.data.vertices,color_layer):
                form.append(vert.co)
                form.append(col)
            
            #for i in range(0, len(pos_layer)-1):
                #form.append(color_layer[i])
              
                #form.append(uv_layer)


            print(form)
            
            
            
            verts_local = [v.co for v in ob.data.vertices.values()]
            verts_world = [ob.matrix_world @ v_local for v_local in verts_local]
            
            form.extend(verts_world)
            form.append((0,0,0))
            form.append((0,0,0))
            form.append((0,0,0))
            for vcol in ob.data.vertex_colors.values():
                for col in vcol.data:
                    form.append(col)
            form.append((0,0,0))
            form.append((0,0,0))
    #print(form)
    
    for ob in bpy.context.scene.objects:
        
            if ob.type == 'CAMERA':
                
                form_n_cam = form
                
                pixels = img.load() # create the pixel map

                for i in range(img.size[0]): # for every pixel:
                    for j in range(img.size[1]):
                        if pixels[i,j] != (255, 0, 0):
                            # change to black if not red
                            pixels[i,j] = (0, 0 ,0)  
'''
# Out:
# "           \ndef render_all_cam_encoder(path):   \n    form = []\n    for ob in bpy.context.scene.objects:\n        if ob.type == 'MESH':\n            \n            \n\n            color_layer = ob.data.vertex_colors\n            pos_layer = ob.data.vertices\n            uv_layer = ob.data.uv_layers.values()\n            for vert, col in zip(ob.data.vertices,color_layer):\n                form.append(vert.co)\n                form.append(col)\n            \n            #for i in range(0, len(pos_layer)-1):\n                #form.append(color_layer[i])\n              \n                #form.append(uv_layer)\n\n\n            print(form)\n            \n            \n            \n            verts_local = [v.co for v in ob.data.vertices.values()]\n            verts_world = [ob.matrix_world @ v_local for v_local in verts_local]\n            \n            form.extend(verts_world)\n            form.append((0,0,0))\n            form.append((0,0,0))\n            form.append((0,0,0))\n            for vcol in ob.data.vertex_colors.values():\n                for col in vcol.data:\n                    form.append(col)\n            form.append((0,0,0))\n            form.append((0,0,0))\n    #print(form)\n    \n    for ob in bpy.context.scene.objects:\n        \n            if ob.type == 'CAMERA':\n                \n                form_n_cam = form\n                \n                pixels = img.load() # create the pixel map\n\n                for i in range(img.size[0]): # for every pixel:\n                    for j in range(img.size[1]):\n                        if pixels[i,j] != (255, 0, 0):\n                            # change to black if not red\n                            pixels[i,j] = (0, 0 ,0)  \n"

# %% [markdown]
# ### clear_scene()
#
#     Generic scene clearing function

# %%
def clear_scene():
    bpy.ops.object.select_all(action='SELECT')
    bpy.ops.object.delete()

# %% [markdown]
# ### Create Material
#     creates a basic vertex color material in blender node editor

# %%
material = bpy.data.materials.get("Material")

if material is None:
    # create material
    material = bpy.data.materials.new(name="Material")
    material.use_nodes = True

    Diffuse_output = material.node_tree.nodes.get('Principled BSDF')
    VertexCol = material.node_tree.nodes.new('ShaderNodeVertexColor')


    # link emission shader to material
    material.node_tree.links.new(Diffuse_output.inputs[0], VertexCol.outputs[0])

# %% [markdown]
# ## Print functions
#
#     the colmap import prints out a lot of data so I added these in so it was easier to track the progress.
#     jupyter notebook also has a non default sys.stdout so I saved it for refrence.

# %%
sys_out = sys.stdout
def blockPrint():
    sys.stdout = open(os.devnull, 'w')

# Restore
def enablePrint():
    sys.stdout = sys_out

# %% [markdown]
# ## Main Render loop
#
#     runing through the the folders in the Rocks directory, checking if all the components exist
#     in the directory and then processing it, outputting the renders in a new sub directory called
#     'renderImages_Exr'

# %%
files = glob.glob(Path+'Rocks/*/')
print(len(files))
    
num=0
for rockdir in files:
    clear_scene()
    timer = time.time()
    blockPrint()
    if loadScene(rockdir):
        enablePrint()    
        render_all_cam(rockdir+"renderImages_Exr/", 512, (0,0,0, 0))
        num+=1
    else:
        enablePrint()
        print('fail')
    print("Time in Mins:")
    print((time.time()-timer)/60)
    print(str(num)+"of"+str(len(files)))
    print("done")
# Out:
# 144
# Info: Deleted 45 object(s)
# Time in Mins:
# 0.09315592845280965
# 1of144
# done
# Info: Deleted 28 object(s)
# Time in Mins:
# 0.04068542718887329
# 2of144
# done
# Info: Deleted 20 object(s)
# Time in Mins:
# 0.08424564202626546
# 3of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.09287506739298503
# 4of144
# done
# Info: Deleted 30 object(s)
# Time in Mins:
# 0.10574572483698527
# 5of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.020409123102823893
# 6of144
# done
# Info: Deleted 12 object(s)
# Time in Mins:
# 0.030148224035898844
# 7of144
# done
# Info: Deleted 19 object(s)
# Time in Mins:
# 0.08619121313095093
# 8of144
# done
# Info: Deleted 39 object(s)
# Time in Mins:
# 0.12053001324335734
# 9of144
# done
# Info: Deleted 54 object(s)
# Time in Mins:
# 0.20830729007720947
# 10of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.11582736968994141
# 11of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.13976333141326905
# 12of144
# done
# Info: Deleted 60 object(s)
# Time in Mins:
# 0.2775170842806498
# 13of144
# done
# Info: Deleted 61 object(s)
# Time in Mins:
# 0.11833581129709879
# 14of144
# done
# Info: Deleted 45 object(s)
# Time in Mins:
# 0.09980162382125854
# 15of144
# done
# Info: Deleted 55 object(s)
# Time in Mins:
# 0.16818302472432453
# 16of144
# done
# Info: Deleted 46 object(s)
# Time in Mins:
# 0.17436029116312662
# 17of144
# done
# Info: Deleted 48 object(s)
# Time in Mins:
# 0.1394017736117045
# 18of144
# done
# Info: Deleted 55 object(s)
# Time in Mins:
# 0.08631703853607178
# 19of144
# done
# Info: Deleted 29 object(s)
# Time in Mins:
# 0.11443796157836914
# 20of144
# done
# Info: Deleted 46 object(s)
# Time in Mins:
# 0.20419134298960367
# 21of144
# done
# Info: Deleted 56 object(s)
# Time in Mins:
# 0.08296016454696656
# 22of144
# done
# Info: Deleted 17 object(s)
# Time in Mins:
# 0.210762886206309
# 23of144
# done
# Info: Deleted 48 object(s)
# Time in Mins:
# 0.1019137700398763
# 24of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.06500256061553955
# 25of144
# done
# Info: Deleted 16 object(s)
# Time in Mins:
# 0.07776381572087605
# 26of144
# done
# Info: Deleted 44 object(s)
# Time in Mins:
# 0.25386542081832886
# 27of144
# done
# Info: Deleted 53 object(s)
# Time in Mins:
# 0.021745745340983072
# 28of144
# done
# Info: Deleted 13 object(s)
# Time in Mins:
# 0.07118404706319173
# 29of144
# done
# Info: Deleted 28 object(s)
# Time in Mins:
# 0.16411767403284708
# 30of144
# done
# Info: Deleted 45 object(s)
# Time in Mins:
# 0.31712156534194946
# 31of144
# done
# Info: Deleted 66 object(s)
# Time in Mins:
# 0.2040684978167216
# 32of144
# done
# Info: Deleted 58 object(s)
# Time in Mins:
# 0.0002840240796407064
# 32of144
# done
# Info: Deleted 0 object(s)
# Time in Mins:
# 0.032021164894104004
# 33of144
# done
# Info: Deleted 13 object(s)
# Time in Mins:
# 0.07387076218922933
# 34of144
# done
# Info: Deleted 30 object(s)
# Time in Mins:
# 0.22044586737950642
# 35of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.02734847068786621
# 36of144
# done
# Info: Deleted 17 object(s)
# Time in Mins:
# 0.12805078824361166
# 37of144
# done
# Info: Deleted 45 object(s)
# Time in Mins:
# 0.09982556104660034
# 38of144
# done
# Info: Deleted 23 object(s)
# Time in Mins:
# 0.16957786083221435
# 39of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.17232208251953124
# 40of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.03252768516540527
# 41of144
# done
# Info: Deleted 20 object(s)
# Time in Mins:
# 0.15203875303268433
# 42of144
# done
# Info: Deleted 53 object(s)
# Time in Mins:
# 0.05467050870259603
# 43of144
# done
# Info: Deleted 28 object(s)
# Time in Mins:
# 0.024042407671610515
# 44of144
# done
# Info: Deleted 17 object(s)
# Time in Mins:
# 0.11345696051915487
# 45of144
# done
# Info: Deleted 27 object(s)
# Time in Mins:
# 0.2414503296216329
# 46of144
# done
# Info: Deleted 52 object(s)
# Time in Mins:
# 0.12713082631429037
# 47of144
# done
# Info: Deleted 36 object(s)
# Time in Mins:
# 0.09701891740163167
# 48of144
# done
# Info: Deleted 52 object(s)
# Time in Mins:
# 0.07745301326115926
# 49of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.1489996870358785
# 50of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.10559909343719483
# 51of144
# done
# Info: Deleted 28 object(s)
# Time in Mins:
# 0.0638221303621928
# 52of144
# done
# Info: Deleted 29 object(s)
# Time in Mins:
# 0.03473651806513468
# 53of144
# done
# Info: Deleted 16 object(s)
# Time in Mins:
# 0.07162615855534872
# 54of144
# done
# Info: Deleted 24 object(s)
# Time in Mins:
# 0.08264538844426474
# 55of144
# done
# Info: Deleted 36 object(s)
# Time in Mins:
# 0.054014774163564046
# 56of144
# done
# Info: Deleted 23 object(s)
# Time in Mins:
# 0.13272811969121298
# 57of144
# done
# Info: Deleted 49 object(s)
# Time in Mins:
# 0.017574958006540933
# 58of144
# done
# Info: Deleted 11 object(s)
# Time in Mins:
# 0.07170563141504924
# 59of144
# done
# Info: Deleted 35 object(s)
# Time in Mins:
# 0.14944816033045452
# 60of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.1848142425219218
# 61of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.10354495843251546
# 62of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.11395495335261027
# 63of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.0841882308324178
# 64of144
# done
# Info: Deleted 32 object(s)
# Time in Mins:
# 0.14328107039133708
# 65of144
# done
# Info: Deleted 40 object(s)
# Time in Mins:
# 0.14885839621225994
# 66of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.035496564706166585
# 67of144
# done
# Info: Deleted 17 object(s)
# Time in Mins:
# 0.11678438981374105
# 68of144
# done
# Info: Deleted 43 object(s)
# Time in Mins:
# 0.11797604163487753
# 69of144
# done
# Info: Deleted 39 object(s)
# Time in Mins:
# 0.0005004763603210449
# 69of144
# done
# Info: Deleted 0 object(s)
# Time in Mins:
# 0.17332504590352377
# 70of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.22785427570343017
# 71of144
# done
# Info: Deleted 60 object(s)
# Time in Mins:
# 0.1312687079111735
# 72of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.21200015544891357
# 73of144
# done
# Info: Deleted 66 object(s)
# Time in Mins:
# 0.06461067994435628
# 74of144
# done
# Info: Deleted 16 object(s)
# Time in Mins:
# 0.0013713717460632324
# 74of144
# done
# Info: Deleted 0 object(s)
# Time in Mins:
# 0.1687456210454305
# 75of144
# done
# Info: Deleted 53 object(s)
# Time in Mins:
# 0.022750107447306316
# 76of144
# done
# Info: Deleted 14 object(s)
# Time in Mins:
# 0.07468223969141642
# 77of144
# done
# Info: Deleted 38 object(s)
# Time in Mins:
# 0.10684996843338013
# 78of144
# done
# Info: Deleted 56 object(s)
# Time in Mins:
# 0.15960827271143596
# 79of144
# done
# Info: Deleted 35 object(s)
# Time in Mins:
# 0.17146513859430948
# 80of144
# done
# Info: Deleted 49 object(s)
# Time in Mins:
# 0.10591855446497599
# 81of144
# done
# Info: Deleted 37 object(s)
# Time in Mins:
# 0.10278737942377726
# 82of144
# done
# Info: Deleted 37 object(s)
# Time in Mins:
# 0.07656176487604777
# 83of144
# done
# Info: Deleted 24 object(s)
# Time in Mins:
# 0.12695260842641196
# 84of144
# done
# Info: Deleted 59 object(s)
# Time in Mins:
# 0.07719967365264893
# 85of144
# done
# Info: Deleted 34 object(s)
# Time in Mins:
# 0.1631631056467692
# 86of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.11796004772186279
# 87of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.21960047483444214
# 88of144
# done
# Info: Deleted 46 object(s)
# Time in Mins:
# 0.2389036734898885
# 89of144
# done
# Info: Deleted 49 object(s)
# Time in Mins:
# 0.17856067816416424
# 90of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.11846410036087036
# 91of144
# done
# Info: Deleted 47 object(s)
# Time in Mins:
# 0.08742658694585165
# 92of144
# done
# Info: Deleted 29 object(s)
# Time in Mins:
# 0.17618219455083212
# 93of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.02762389580408732
# 94of144
# done
# Info: Deleted 19 object(s)
# Time in Mins:
# 0.10295293728510539
# 95of144
# done
# Info: Deleted 30 object(s)
# Time in Mins:
# 0.025927011171976724
# 96of144
# done
# Info: Deleted 16 object(s)
# Time in Mins:
# 0.24636481205622354
# 97of144
# done
# Info: Deleted 48 object(s)
# Time in Mins:
# 0.04699321587880453
# 98of144
# done
# Info: Deleted 20 object(s)
# Time in Mins:
# 0.11516969998677572
# 99of144
# done
# Info: Deleted 48 object(s)
# Time in Mins:
# 0.05729052225748698
# 100of144
# done
# Info: Deleted 22 object(s)
# Time in Mins:
# 0.12665817737579346
# 101of144
# done
# Info: Deleted 38 object(s)
# Time in Mins:
# 0.11184376080830892
# 102of144
# done
# Info: Deleted 31 object(s)
# Time in Mins:
# 0.1748295029004415
# 103of144
# done
# Info: Deleted 49 object(s)
# Time in Mins:
# 0.016083943843841552
# 104of144
# done
# Info: Deleted 11 object(s)
# Time in Mins:
# 0.16671992142995198
# 105of144
# done
# Info: Deleted 62 object(s)
# Time in Mins:
# 0.22693405548731485
# 106of144
# done
# Info: Deleted 44 object(s)
# Time in Mins:
# 0.18433114687601726
# 107of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.1334581176439921
# 108of144
# done
# Info: Deleted 37 object(s)
# Time in Mins:
# 0.10819861888885499
# 109of144
# done
# Info: Deleted 26 object(s)
# Time in Mins:
# 0.07214953104654948
# 110of144
# done
# Info: Deleted 32 object(s)
# Time in Mins:
# 0.05786710977554321
# 111of144
# done
# Info: Deleted 26 object(s)
# Time in Mins:
# 0.11993951797485351
# 112of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.08996933301289876
# 113of144
# done
# Info: Deleted 41 object(s)
# Time in Mins:
# 0.09415579239527384
# 114of144
# done
# Info: Deleted 33 object(s)
# Time in Mins:
# 0.15292954842249554
# 115of144
# done
# Info: Deleted 39 object(s)
# Time in Mins:
# 0.1585541566212972
# 116of144
# done
# Info: Deleted 50 object(s)
# Time in Mins:
# 0.04836207628250122
# 117of144
# done
# Info: Deleted 18 object(s)
# Time in Mins:
# 0.08182316621144613
# 118of144
# done
# Info: Deleted 31 object(s)
# Time in Mins:
# 0.21556594371795654
# 119of144
# done
# Info: Deleted 64 object(s)
# Time in Mins:
# 0.026487298806508384
# 120of144
# done
# Info: Deleted 14 object(s)
# Time in Mins:
# 0.07192110220591227
# 121of144
# done
# Info: Deleted 27 object(s)
# Time in Mins:
# 0.021591405073801678
# 122of144
# done
# Info: Deleted 11 object(s)
# Time in Mins:
# 0.14047102530797323
# 123of144
# done
# Info: Deleted 37 object(s)
# Time in Mins:
# 0.11266087293624878
# 124of144
# done
# Info: Deleted 36 object(s)
# Time in Mins:
# 0.09305735031763712
# 125of144
# done
# Info: Deleted 56 object(s)
# Time in Mins:
# 0.0006836811701456706
# 125of144
# done
# Info: Deleted 0 object(s)
# Time in Mins:
# 0.022169562180836995
# 126of144
# done
# Info: Deleted 12 object(s)
# Time in Mins:
# 0.07784676551818848
# 127of144
# done
# Info: Deleted 24 object(s)
# Time in Mins:
# 1.4547506968180338e-05
# 127of144
# done
# Info: Deleted 0 object(s)
# Time in Mins:
# 0.15111801226933796
# 128of144
# done
# Info: Deleted 81 object(s)
# Time in Mins:
# 0.018981440862019857
# 129of144
# done
# Info: Deleted 12 object(s)
# Time in Mins:
# 0.11521260738372803
# 130of144
# done
# Info: Deleted 33 object(s)
# Time in Mins:
# 0.07881786823272705
# 131of144
# done
# Info: Deleted 39 object(s)
# Time in Mins:
# 0.11745662689208984
# 132of144
# done
# Info: Deleted 42 object(s)
# Time in Mins:
# 0.19665739933649698
# 133of144
# done
# Info: Deleted 51 object(s)
# Time in Mins:
# 0.11420023838678996
# 134of144
# done
# Info: Deleted 33 object(s)
# Time in Mins:
# 0.036188570658365886
# 135of144
# done
# Info: Deleted 15 object(s)
# Time in Mins:
# 0.07703097661336263
# 136of144
# done
# Info: Deleted 33 object(s)
# Time in Mins:
# 0.01877209742863973
# 137of144
# done
# Info: Deleted 12 object(s)
# Time in Mins:
# 0.26646173795064293
# 138of144
# done
# Info: Deleted 59 object(s)
# Time in Mins:
# 0.11253739595413208
# 139of144
# done

# %% [markdown]
# ## Merging the dataSet for EXR
#
#     A set of functions that copy and paste all of the rendered .exr and original matching .jpg into one folder.
#     Numbering them in pairs, this is not as secure as having the two sides of the set merged but it worked for
#     in the time scale.

# %%
def load_images_from_folder(folder):
    images = sorted(os.listdir(folder))
   
    return images

# %%
def copy_images(path, num):
    
   # print(path)
    if os.path.exists(path+"images") and  os.path.exists(path+"renderImages_Exr") :
        print(path)
        
        images_base=load_images_from_folder(path+'images/')
        images_render=load_images_from_folder(path+'renderImages_Exr/')
        print(len(images_base))
        
        if len(images_base)==len(images_render):
            for n  in range(0,len(images_base)):
                num+=1
                jpg = images_base[n]
                copyfile(path+'images/'+jpg, os.getcwd()+'/imgDatabase/rockPair-exr/'+str(num).zfill(5)+'.jpg')
                exr = images_render[n]
                copyfile(path+'renderImages_Exr/'+exr, os.getcwd()+'/imgDatabase/rockPair-exr/'+str(num).zfill(5)+'.exr')
        print(len(images_render))    
        return num
        #else:
         #   return num
    else:
        print('fail')
        return num

# %%
allRocks = glob.glob(Path+'/Rocks/*/')

num= len(glob.glob(os.getcwd()+'/imgDatabase/rockPair-exr/*.jpg'))
for rockdir in allRocks:
    timer = time.time()
    num = copy_images(rockdir, num)
    print("Time in Mins:")
    print((time.time()-timer)/60)
    #print(str(num)+"of"+str(totFiles))
    print("done")
print("Actually Done!!!!")

# %% [markdown]
# ## Merge Dataset for .jpg
#
#     For the original pix2pix setup, this checks the image set bothe exist and then merges them into one solid
#     .jpg ready for training, saving all the merged into a single folder ready for splitting into train and
#     test.

# %%
def load_images_from_folder(folder):
    images = []
    for filename in sorted(os.listdir(folder)):
        img = Image.open(os.path.join(folder,filename))
        if img is not None:
            images.append(img)
    return images

# %%
def merge_imagesDataset(path, num):
    
   # print(path)
    if os.path.exists(path+"images") and  os.path.exists(path+"renderImages") :
      
        
        images_base=load_images_from_folder(path+'images/')
        images_render=load_images_from_folder(path+'renderImages/')
        
        if len(images_base)==len(images_render):
            for n  in range(0,len(images_base)):
                images_2_merge = [images_base[n],images_render[n]]
                widths, heights = zip(*(i.size for i in images_2_merge))
                total_width = sum(widths)
                max_height = max(heights)
                new_im = Image.new('RGB', (total_width, max_height))
                new_im.paste(images_render[n],(widths[0],0))
                new_im.paste(images_base[n], (0,0))


                num+=1
                new_im.save(os.getcwd()+'/imgDatabase/rockPair_wireframe/'+str(num).zfill(5)+'.jpg')
        print(len(images_render))    
        return num
        #else:
         #   return num
    else:
        print('fail')
        return num

# %%
allRocks = glob.glob(Path+'/Rocks/*/')
print(len(allRocks))
num= 2668
for rockdir in allRocks:
    timer = time.time()
    num = merge_images(rockdir, num)
    print("Time in Mins:")
    print((time.time()-timer)/60)
    #print(str(num)+"of"+str(totFiles))
    print("done")
print("Actually Done!!!!")
